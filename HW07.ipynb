# %% [markdown]
# ## Домашнее задание №7
# ### Генерация поэзии с помощью нейронных сетей: шаг 1
# ##### Авторы: [Радослав Нейчев](https://www.linkedin.com/in/radoslav-neychev/), Горохов Олег
#
# Ваша основная задача: научиться генерировать стихи с помощью простой рекуррентной нейронной сети (Vanilla RNN). В качестве корпуса текстов для обучения будет выступать роман в стихах "Евгений Онегин" Александра Сергеевича Пушкина.

# %%
# Не меняйте блок кода ниже! Здесь указаны все необходимые import-ы
# __________start of block__________
import string
import os
from random import sample

import numpy as np
import torch, torch.nn as nn
import torch.nn.functional as F

from IPython.display import clear_output

import matplotlib.pyplot as plt
# %matplotlib inline
# __________end of block__________

# %%
# Не меняйте блок кода ниже!
# __________start of block__________
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('{} device is available'.format(device))
# __________end of block__________
# Out:
# cuda device is available

# %% [markdown]
# #### 1. Загрузка данных.

# %%
# do not change the code in the block below
# __________start of block__________
# !wget https://raw.githubusercontent.com/MSUcourses/Data-Analysis-with-Python/main/Deep%20Learning/onegin_hw07.txt -O ./onegin.txt

with open('onegin.txt', 'r') as iofile:
    text = iofile.readlines()

text = "".join([x.replace('\t\t', '').lower() for x in text]) # Убираем лишние символы табуляций, приводим все буквы к нижнему регистру
# __________end of block__________
# Out:
# --2023-12-02 20:58:13--  https://raw.githubusercontent.com/MSUcourses/Data-Analysis-with-Python/main/Deep%20Learning/onegin_hw07.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262521 (256K) [text/plain]
# Saving to: ‘./onegin.txt’
#
# ./onegin.txt        100%[===================>] 256.37K  --.-KB/s    in 0.005s
#
# 2023-12-02 20:58:14 (54.1 MB/s) - ‘./onegin.txt’ saved [262521/262521]

# %% [markdown]
# Выведем несколько первых символов входного текста. Видим, что символы табуляций удалены, буквы приведены к нижнему регистру. Символы \n мы оставляем - чтобы научить сеть генерировать символ \n, когда нужно перейти на новую строку.

# %%
text[:36]
# Out:
# '\ni\n\n«мой дядя самых честных правил,\n'

# %% [markdown]
# #### 2. Построение словаря и предобработка текста
# В данном задании требуется построить языковую модель на уровне символов. Приведем весь текст к нижнему регистру и построим словарь из всех символов в доступном корпусе текстов. Также добавим технический токен `<sos>`.

# %%
# Не меняйте блок кода ниже!
# __________start of block__________
tokens = sorted(set(text.lower())) + ['<sos>'] # Строим множество всех токенов-символов и добавляем к нему служебный токен <sos>
num_tokens = len(tokens)

assert num_tokens == 84, "Check the tokenization process"

token_to_idx = {x: idx for idx, x in enumerate(tokens)} # Строим словарь с ключами-токенами и значениями-индексами в списке токенов
idx_to_token = {idx: x for idx, x in enumerate(tokens)} # Строим обратный словарь (чтобы по индексу можно было получить токен)

assert len(tokens) == len(token_to_idx), "Mapping should be unique"

print("Seems fine!")


text_encoded = [token_to_idx[x] for x in text]
# __________end of block__________
# Out:
# Seems fine!

# %% [markdown]
# __Ваша задача__: обучить классическую рекуррентную нейронную сеть (Vanilla RNN) предсказывать следующий символ на полученном корпусе текстов и сгенерировать последовательность длины 100 для фиксированной начальной фразы.
#
# Вы можете воспользоваться кодом с занятия №6 или же обратиться к следующим ссылкам:
# * Замечательная статья за авторством Andrej Karpathy об использовании RNN: [link](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
# * Пример char-rnn от Andrej Karpathy: [github repo](https://github.com/karpathy/char-rnn)
# * Замечательный пример генерации поэзии Шекспира: [github repo](https://github.com/spro/practical-pytorch/blob/master/char-rnn-generation/char-rnn-generation.ipynb)
#
# Данное задание является достаточно творческим. Не страшно, если поначалу оно вызывает затруднения. Последняя ссылка в списке выше может быть особенно полезна в данном случае.
#
# Далее для вашего удобства реализована функция, которая генерирует случайный батч размера `batch_size` из строк длиной `seq_length`. Вы можете использовать его при обучении модели.

# %%
# Не меняйте код ниже
# __________start of block__________
batch_size = 256 # Размер батча. Батч - это набор последовательностей символов.
seq_length = 100 # Максимальная длина одной последовательности символов в батче
start_column = np.zeros((batch_size, 1), dtype=int) + token_to_idx['<sos>'] # Добавляем в начало каждой строки технический символ - для определения начального состояния сети

def generate_chunk():
    global text_encoded, start_column, batch_size, seq_length

    start_index = np.random.randint(0, len(text_encoded) - batch_size*seq_length - 1) # Случайным образом выбираем индекс начального символа в батче
    # Строим непрерывный батч.
    # Для этого выбираем в исходном тексте подпоследовательность, которая начинается с индекса start_index и имеет размер batch_size*seq_length.
    # Затем мы делим эту подпоследовательность на batch_size последовательностей размера seq_length. Это и будет батч, матрица размера batch_size*seq_length.
    # В каждой строке матрицы будут указаны индексы
    data = np.array(text_encoded[start_index:start_index + batch_size*seq_length]).reshape((batch_size, -1))
    yield np.hstack((start_column, data))
# __________end of block__________

# %% [markdown]
# Пример батча:

# %%
next(generate_chunk())
# Out:
# array([[83, 50, 61, ..., 48, 45, 57],
#        [83, 53,  0, ..., 61, 76, 48],
#        [83, 45, 75, ..., 57, 45, 63],
#        ...,
#        [83, 57, 68, ..., 49, 64, 69],
#        [83, 53,  1, ..., 53, 58, 76],
#        [83,  1, 60, ..., 53, 62, 73]])

# %% [markdown]
# Далее вам предстоит написать код для обучения модели и генерации текста.

# %%
class CharRNN(nn.Module):
    def __init__(self, num_tokens=num_tokens, emb_size=16, hidden_size=64, num_layers=1):
        super().__init__()
        self.emb = nn.Embedding(num_tokens, emb_size)
        self.rnn = nn.RNN(emb_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_tokens)

    def forward(self, x, hidden=None):
        x = self.emb(x)
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden

# %% [markdown]
# В качестве иллюстрации ниже доступен график значений функции потерь, построенный в ходе обучения авторской сети (сам код для ее обучения вам и предстоит написать).

# %%
# Создаем модель и переносим ее на выбранное устройство
char_rnn = CharRNN().to(device)

# Задаем функцию потерь и оптимизатор
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(char_rnn.parameters())

# Количество эпох и интервал для вывода графика
num_epochs = 1000
plot_interval = 50

history = []

for epoch in range(num_epochs):
    # Генерируем батчи
    for batch in generate_chunk():
        # Обнуляем градиенты
        optimizer.zero_grad()

        # Преобразуем данные и переносим их на выбранное устройство
        batch = torch.tensor(batch, dtype=torch.int64).to(device)
        inputs = batch[:, :-1]
        targets = batch[:, 1:]

        # Прогоняем данные через модель и вычисляем функцию потерь
        outputs, _ = char_rnn(inputs)
        loss = loss_function(outputs.contiguous().view(-1, num_tokens), targets.contiguous().view(-1))

        # Обновляем параметры модели
        loss.backward()
        optimizer.step()

        # Записываем значение функции потерь
        history.append(loss.item())

    # Выводим график функции потерь
    if (epoch + 1) % plot_interval == 0:
        clear_output(True)
        plt.plot(history, label='loss')
        plt.legend()
        plt.show()

# %% [markdown]
# Шаблон функции `generate_sample` также доступен ниже. Вы можете как дозаполнить его, так и написать свою собственную функцию с нуля. Не забывайте, что все примеры в обучающей выборке начинались с токена `<sos>`.

# %%
def generate_sample(char_rnn, seed_phrase=None, max_length=200, temperature=1.0, device=device):
    char_rnn.eval()
    with torch.no_grad():
        if seed_phrase is not None:
            x_sequence = [token_to_idx['<sos>']] + [token_to_idx[token] for token in seed_phrase]
        else:
            x_sequence = [token_to_idx['<sos>']]

        x_sequence = torch.tensor([x_sequence], dtype=torch.int64).to(device)
        hidden = None

        for _ in range(max_length - len(seed_phrase)):
            outputs, hidden = char_rnn(x_sequence[:, -1].unsqueeze(1), hidden)
            probabilities = F.softmax(outputs / temperature, dim=-1)
            next_token = torch.multinomial(probabilities.squeeze(), num_samples=1)
            x_sequence = torch.cat([x_sequence, next_token.unsqueeze(1)], dim=1)

    return ''.join([tokens[ix] for ix in x_sequence.cpu().data.numpy()[0]])

# %% [markdown]
# Пример текста сгенерированного обученной моделью доступен ниже. Не страшно, что в тексте много несуществующих слов. Используемая модель очень проста: это простая классическая RNN.

# %%
generated_phrases = [
    generate_sample(
        char_rnn,
        ' мой дядя самых честных правил',
        max_length=500,
        temperature=1.
    ).replace('<sos>', '')
    for _ in range(10)
]

for idx, phrase in enumerate(generated_phrases):
    print(f"Phrase {idx + 1}:")
    print(phrase)
    print("\n")
# Out:
# Phrase 1:
#  мой дядя самых честных правильната мном
# дскрянуень» «сё
# че ней мы чога
# замнает,
# сто плехонот:
# прерной перешывамарьно тет обесотит, содно тривела
# ъытовор пол
# кахояньло догою забевьли,
# за нлюбисть не цари.
#
#
#
# xl
# томенняя с мискайстью: ловоек
# как в онегре у ня в ен поласанкив либил смодошмых на пруд ворваня нишезденем суджеет слувельной, доло от; за свено, я стале сушитый!
# еать,
# и пушу лжянье шуфи члогиннахо скородя  с блашены фуды,
# рестотежат ни в я сненье ды и им рада логокой:
# в скае;
# тетил осто
#
#
# Phrase 2:
#  мой дядя самых честных правилю ей ланкали им кодет и тюшнам лю релятя; мничаний
#
#
#
# li
#
# попрысть не глязных никоволок керезкаеньа ведит лечим сиды, м пупарьй
# ленемно михомся прачетит мепнает мою такте,
# то доли,
# ой раздцей буждролочать свотродой;
# иныры...
#
#
#
# lxxv
#
# )
# вез:
# предь он безам оз гестолн он думае гживовша
# и готой чути,
# анный делой,:
# помней
#
#
#
# xxi
#
# иглилу, зегивила обимитбали уш суг ном столатьесь и хлобое и не правы струзилерыо мне презали;
# вы в велосам обта риселжений сериную шухстольда
#
#
# Phrase 3:
#  мой дядя самых честных правилящу;
# и ном он взарною мная,
# горыo.
# еегой неднов,
# донною:
# спрашат, начлоро песлей.
# и ниинийнужил она в вно
# как распилмит я взембеньах илодих помднавый пометне дце ша.
# шукно, жжейавьо!
# пив итминье дуды: на дуют накель течной и зетек ричиный, гласчада зазде продрася,
# пловутсяний вадкие чегой
# устав
# костолином он возном желкахсски брурьова
# в бед стелок
# иль погоерьнь
# посясь бым преды,
# здовости сриком (ельной гладьен подитовать: ниспар возвител
# иа одна вленанною купвас— ня
#
#
# Phrase 4:
#  мой дядя самых честных правилья не стасень
# к грютя полавнови,
# и левобит,
# и чливью душей досыверуские изменя
# мы, – почяй
# и жу гинатьень от…
# как туша».
#
#
#
# xxxix
#
# хот вюмом.
# семдых и бырень;
# вля внядет;
# нак
# ена тимо в свост!
# и желю девичанить
# скиждат язил, провчек
#
#
# xxii
#
# ктоболит ливенно лиц,
# осныче, чуста позвурдца
# и же вотомая кода мумя на… собнов,
# и «поюзже лем,
# он мид невящене
# и петя прихон ихозами томко призлимя.
# и лодае.
# «:
# грядный
# то внегда на празань:
# так ихарои сорьтась онесной случать н
#
#
# Phrase 5:
#  мой дядя самых честных правилойлась задеятеть укуских
# можел?.
# хо дане т;
# ах одная поздро та!
# увед,
# и кан меряд уведопого на женой но
# у, i бридой ков миду позда ней онала
# про:!
# острывять лидожа,
# при бышся сатчалья селье я,
# омьго. «с вети бутини:
# с верям угрускь онемной,
# ве мол, бы олыца суда мона лежконым одно,
# что о как
# оя леной,
# тотьбныы лги!
#
#
#
# xi
#
# дарум,
# ностотый скавовый,
# подыский,
# полагой;
# вехих ей муевныцой;
# зарит:
# весать в судена, двил
# и в сни нак мле г луборит.
# он пристив, воднов: чим,
#
#
# Phrase 6:
#  мой дядя самых честных правилых помный вароменно о в дезны вглась, прогосет.
# —
# «чтрек,
# а… хошта, вотрость ес
#
#
#
# vii
#
# пол!али в» мый олуть грузды -сбоем,
# и терь дашась кыто там пикойск ономой стала лько демный не-кузводнык,
# телы вся но уводный секиг
# ворной;
# в дель гых
# ои г сней.
# ам и причвия его ны езется неместе, зи ъечто на пуздойка
# зы в коди,
# n
#
# ра заверал пудий
# и посту душа.
# xi
#
# обень какал. на поданое.
# тре шерствае всешный
# уж емя содчанала личитил молкой ресе, роздаю, од-по дояка, маром,
# ра
#
#
# Phrase 7:
#  мой дядя самых честных правилаза лизые в гоемна;
# на тетель, потой,
# с[ёгой труде, за жд,
# сствае дуло,
# тавы! нак носпоресь.
# и не октошит бестраждый,
# снами хосел
# имо разери, оболю дотно дле на, мен бытьа нны будруше
# ни прешдо побы на в перятым поратвов:
# пруярское,
# отрывана медсуе пелой,
# десовой
# ды дутья, в тшое сте вам водих таемный одейдам ды
# турьки, а бужь.
# м и бала».
#
#
#
# xxxix
# sвердынашиям
# расудет, пящу вникой неча небрудско вылябая меaвпе пруходь,
# едрадунел поспаки ветрань ототналисть бахолико!
#
#
# Phrase 8:
#  мой дядя самых честных правилюкай;
# былся, я свочел итоко став любеть в саль, не воснам нео везасью
# к линною
# , эта но нрюшчесний онет ей сездки стояроне любвою раше бендитась батото струши к даv
#  межд; нотелать
# и мендый тебная,
# таховоцлютвих он спятрежно воседит?
# в варкы; деть собнаша;
# врагдаскамди раш, холет волсков, чегрезяколькой кань жн;
# пролос вери своq
# «свнодной,
# по т этесь,
# по цу римве серскя,
# вневе, вореро рак
# предетной
# ивод, ней замемный заморовенысь,
# даа повер!
# от отпоривон и мпебет по
#
#
# Phrase 9:
#  мой дядя самых честных правилиймунья
# игуща.
# «е тий сестрывый он зострий стя риндоной.
#
#
#
# xl
#
# ислим о колналь их олеюзни кнократа
# ссполяла и барам,
# привлимирой аскоброж нечстахал!
# прастрах воскоро прочах
# на жен поратью мильский сталон мерезы моеска
# нчаладьний
# тамоя стородин сохы! и лятклив угроковет;
# солодорчал,
# орко
# скуздолу стял пришена
# и кук очты добешный уверьно:
# я радские удить,
# яда сане том!
# и витрый щилlет
# напутья,
# кров. нем мор вводиный маещик, скути вергану мздше, глухии дурый сноглинан
#
#
# Phrase 10:
#  мой дядя самых честных правилыхоть…
# и безарнуесь
# вол
# на,
# поежда,
# дали духит… на
# дуроюне
# похолельи
# с мумно ой ноль остресне,
# кана содений зиму дажелил!
# еную он, тавлянуе: уж невамный зйом онаваной,
# любришит из от эти не мистин в серлунся мыжный.
# паже берд,
# невдрехки на и;
# воскояньный
# леногисты таньним не видать селеднога,
# вна езит,
# з стабет опростной ненс послива пестойтусь помналгой,.
#
#
#
# li
#
# ногда чу,
# онеймял»,
# парскини.
# ни мостим вездавил?».
# гритых от!
# завска.
# она
# цет ни зашум у на брядеят
# нен

# %% [markdown]
# ### Сдача задания
# Сгенерируйте десять последовательностей длиной 500, используя строку ' мой дядя самых честных правил'. Температуру для генерации выберите самостоятельно на основании визуального качества генериуремого текста. Не забудьте удалить все технические токены в случае их наличия.
#
# Сгенерированную последовательность сохрание в переменную `generated_phrase` и сдайте сгенерированный ниже файл в контест.

# %%
seed_phrase = ' мой дядя самых честных правил'

# %%
generated_phrases = [
    generate_sample(
        char_rnn,
        ' мой дядя самых честных правил',
        max_length=500,
        temperature=1.0
    ).replace('<sos>', '')
    for _ in range(10)
]

for idx, phrase in enumerate(generated_phrases):
    print(f"Phrase {idx + 1}:")
    print(phrase)
    print("\n")
# Out:
# Phrase 1:
#  мой дядя самых честных правильскук, ливать. —
# « оными,
# ин! надою
# пввосси, приновскный
# и све быми ликоr, причье влесно позралений поя стовесте
# ского сти знетня!
# ватный всту молодогнорость оспелик,
# ий жта помоновбовда
# начуд;
# падори,
# и кашчою димась очавый мбевный,
# гедрую слешны,
# годо не пыл
# драгили
# доленье,
# пове, не свей градать – моярок милохить не можь о ды:
# растыю
# к браги
# ктад мисто в кенодень» в:
# гдрешном, ч туктя тить евнык еслой,
# на нрасежным,
# а-когда потных ридушнь влед ее жечни: не выэт п
#
#
# Phrase 2:
#  мой дядя самых честных правилыхристит.
# с даралима на мивосных
# алого,
# то кудров жемну? чспуравье не позда хруз?
# в и бежер доватный очелье,
# пра враня… стали, уж у когос;-и тилай!
# престаенны, цду йкиму на де, когой
# онегоной лью;
#
#
#
# ix
#
# гоядил;
# она хружнас
# кажел
# и потрив
#
#
#
# xxvi
#
# зебатных ка гиной;
#
#
#
# xx
#
# разшят думали прудьк ом за что стух сескогил лучта судале
# рапитерая, долюный
# оних деро.
#
#
# я лесьит, мей дар рошь наморь;
# не хре сную похо таки сопуднно былый мепи;
# о лейь радьмо иль леже рещень.
#
#
#
#
# Phrase 3:
#  мой дядя самых честных правильень
#
#
#
# xl!
#
# чего сты неженном несты все побыл ня ж сегды дрямоли! иникива, тло граря жир
# провыя хозепеть еду клучинлай дуежний тотвое ните»…
# слашной онде,
# дах о моивней,
# то номят,
# сaва…,
# посесь в с презарала дкой счест,
# в сопет рустах, к ток одрых тагись,
# и но ужетел,
# туше слезери
# итовахся;
# на гоносье гдалат, побьбы, там желсяка,
# что неча педед-покам не дотой
# всегой,
# плечтека
# искол ком лацным годаньков
# годня;
#
# о приводит врем предрусь,
# хоэних вобнец –ото дерерчи к
#
#
# Phrase 4:
#  мой дядя самых честных правиливзи ког,
# где эторенние за сомынен;
# кначуч… тольних,
# елових нецеминая ставам;
# рою!
# занель,
# чеменая сле(гой плотля брастыстек их
# любки как вод лукныл, танщется какным, нахмомыт
# с перли гналет,
# стопиленые болченский мудой предокоть. мутоль ругую раг, пумы не
# нагоспелдакно сказа,баивает.
# цви дастолочя ивсмол.
#
#
#
# xxiцi
#
# мийха водрит ни нны пошной;
# в годой где живитски.
# и залсе свил, как, довот но модне…
# был стороть онасядный льбо боган оетроюна рапрочкой.
#
#
#
# xxxi!
#
#
#
# xx
#
#
# Phrase 5:
#  мой дядя самых честных правил!
# вебнок.
#
#
#
#
# vl
#
#
#
#
# xlxii:
#
# на пракрезеной тово, ни брад; ктитьен егол?
# онт…
# ничтый по. гочалья
# нажелью онатетсу заснешерить.
#
#
#
# xxx?
#
# в дичат
# и гне,
# онут»ым рошем незсе, усказде зремась зазноет осторов яди судена!
# яля блезно,
# полела.
# сечне лсе каз!
# в сляжих.
# стерень,
# ужил
# она двнивон
# часерь.
#
#
#
# xxxvii
#
# тет любной,
# и нибуотьелшцу подде сляшкам; спвла:
# стале тень-лен
# татели?
# кого и оспреньжихствой к любы
# в негонит,
# зромлон
# сполед:
# качать но весудно упрудуе тавна всё
#
#
# Phrase 6:
#  мой дядя самых честных правилюба в двернаяли,
# еда линай.
# и неестал он не мельный побдрислетем пружду не верконо»
# тлала
# ков вадном цольбе
# стутью двей,
# поятре, пиший передевалиной,
# но ногилот;
# в отвви,
# ире водяратель ший? чея,
# ссеw
#
#
#
# xxiii
#
# измам е татьяташо стдоть,
# убраскей
# поглучий.
#
#
#
# xxviх
# я нелчуюстьяй ний. – хлядил.
#
#
#
# xxviv
# i пыбыет
# скаробний,
# жузв
# и обтале
# ича замно ваоны любровают;
# но лачно.
# призуте свельни среру!
# момолов.
# мымбвит;
# оне тый,
# и
# дмуша зомно плечат;
# и нестотико,
# и вляве; сл
#
#
# Phrase 7:
#  мой дядя самых честных правильки
# и оль жкаленней;
# кым
# скрежет в боянемно.
#
#
#
# xliii
#
# ей быфнчее том,
# призду лад)
# уж и пров попроты, не иль ходнапи, кавской
# пругое воц.
# размегиесть и в чеждля ок
# поень,
# хук но вечесты сомоги ред(ста полнить,
# ольней провпесны
# дровств
# одевно кражене
# вачто и нисные, негученных:
# дельнет на вье,
# егость, хва. —
# «чта вы стихояа строели,
# годаваный то реледет –сё,
# посее и прикитьбны, л
# поэт…
# аной варде де-тых иной.
#
#
# xxxi
#
# о стринали? чатил
# лесок,
# ночим яновье утым нерныт
#
#
# Phrase 8:
#  мой дядя самых честных правилий,
# умять емняе
# чез
#
#
#
# xlv
#
# глодне
# брим узразный не леть бвизну д-тощо,
# д воз к паре,
# проскиккери.
# на потил:
# онеграпоней.
# крестовет душе мне.
# приверу дней ялью о бав.
#
#
#
# xlvi
#
# лобылся плаши, доть она
# не любян:
#
#
#
#
# xxxiii
#
# бы семся опродакавуя зачтое плугдят на вдесеча у тамих поре доммеле: убраздых зне хошясь тосталий
# прузонуой,
# блимну таты накноз
# уат неготреле могосяляной,
# кик…
# кощско,
# толо смем дрожди двит, свсевол: дорого пригаме,
# и кол, суд…
# дно,
# вужны яхь яс от
#
#
# Phrase 9:
#  мой дядя самых честных правиль склидил песто плкизны,
# танья;
# но свой пибей
# взалость.
# вров мох ео подноча
# к та душны одивить золода лезго в горий а с блостет дере пос рашесчепиких невот;
# едитсмоно
# ка!
# повдалендаястся, и песобеда,
# токамат;
# у нствой,
# прись стомилье счаствмени знок. – ленью стразел и продса сщидиб свитма музяла,
# пушак
#
#
#
# xxii
# »
#
# ожы всет
# егре?ствы,
# и мудит из мемисто й тогу, ни толенья, негого порскив йно… кумом,
# и скорот прикае режбаншето душдевой,
# и чей,
# на то на увидет оиму двих
#
#
# Phrase 10:
#  мой дядя самых честных правилушь ташь, ресташа… сад…
# намоландать давокою плыжь.
# но звор: и воспристью мол?ве
# увететь трилим
# и пошошер,
# на пасья?
# …олерла,
# набтал не подлу?,
# и ста узраванье блазрали,
# татьял.
#
#
#
# xxxxxe
#
# нойеть
# на чзамуся ды?» «гидие оненкко бальный лю глусть, соедой.
# креги терталемные жчат;
# она горась,
# сворорем и длувать.
# как всегдрана
# на смечида.
# бымиль не ненси дая ворорном
# до дувмише, молют ез чтобил воздал я занам али возрима тумослатет: у тряпят;
# него друзьюбе мечно лаз четь

# %%
# do not change the code in the block below
# __________start of block__________

if 'generated_phrases' not in locals():
    raise ValueError("Please, save generated phrases to `generated_phrases` variable")

for phrase in generated_phrases:

    if not isinstance(phrase, str):
        raise ValueError("The generated phrase should be a string")

    if len(phrase) != 500:
        raise ValueError("The `generated_phrase` length should be equal to 500")

    assert all([x in set(tokens) for x in set(list(phrase))]), 'Unknown tokens detected, check your submission!'


submission_dict = {
    'token_to_idx': token_to_idx,
    'generated_phrases': generated_phrases
}

np.save('submission_dict_hw07.npy', submission_dict, allow_pickle=True)
print('File saved to `submission_dict_hw07.npy`')
# __________end of block__________
# Out:
# File saved to `submission_dict_hw07.npy`

# %% [markdown]
# На этом задание завершено. Поздравляем!
